# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from collections import Counter

# %%
sw_dic = []
with open("C:/Users/supin/Desktop/starwars/SW_EpisodeV.txt", "r") as text:
    text = text.readlines()[1:]  #skip first line
    for line in text:
        line = line.lower().split('"') #lowercase all words and split by quotes
        dialogue = line.pop(5)
        name = line.pop(3)
        line_number = line.pop(1)
        new_obj = {
            "line": line_number,
            "name": name,
            "dialogue": dialogue
        }
        sw_dic.append(new_obj)
#print out each line separately by line number, character name, and dialogue
print(sw_dic)
# Out:
# [{'line': '1', 'name': 'luke', 'dialogue': 'echo three to echo seven. han, old buddy, do you  read me?'}, {'line': '2', 'name': 'han', 'dialogue': "loud and clear, kid. what's up?"}, {'line': '3', 'name': 'luke', 'dialogue': "well, i finished my circle. i don't pick up any  life readings."}, {'line': '4', 'name': 'han', 'dialogue': "there isn't enough life on this ice cube to fill a  space cruiser. the sensors are placed. i'm going back."}, {'line': '5', 'name': 'luke', 'dialogue': "right. i'll see you shortly. there's a meteorite  that hit the ground near here. i want to check it out. it won't take long."}, {'line': '6', 'name': 'luke', 'dialogue': "hey, steady girl. what's the matter? you smell something?"}, {'line': '7', 'name': 'luke', 'dialogue': 'aaargh!'}, {'line': '8', 'name': 'han', 'dialogue': 'chewie!'}, {'line': '9', 'name': 'han', 'dialogue': "all right, don't lose your temper. i'll come right back and give  you a hand."}, {'line': '10', 'name': 'rieekan', 'dialogue': 'solo?'}, {'line': '11', 'name': 'han', 'dialogue': "no sign of life out there, general. the sensors are in place.  you'll know if anything comes around."}, {'line': '12', 'name': 'rieekan', 'dialogue': 'commander skywalker reported in yet?'}, {'line': '13', 'name': 'han', 'dialogue': "no. he's checking out a meteorite that hit near him."}, {'line': '14', 'name': 'rieekan', 'dialogue': "with all the meteor activity in this  system, it's going to be difficult to spot approaching ships."}, {'line': '15', 'name': 'han', 'dialogue': "general, i've got to leave. i can't stay anymore."}, {'line': '16', 'name': 'rieekan', 'dialogue': "i'm sorry to hear that."}, {'line': '17', 'name': 'han', 'dialogue': "well, there's a price on my head. if i don't pay off jabba the  hut, i'm a dead man."}, {'line': '18', 'name': 'rieekan', 'dialogue': "a death mark's not an easy thing to live with. you're a good  fighter, solo. i hate to lose you."}, {'line': '19', 'name': 'han', 'dialogue': 'thank you, general.'}, {'line': '20', 'name': 'han', 'dialogue': 'well, your highness, i guess this is it.'}, {'line': '21', 'name': 'leia', 'dialogue': "that's right."}, {'line': '22', 'name': 'han', 'dialogue': "well, don't get all mushy on me. so long, princess."}, {'line': '23', 'name': 'leia', 'dialogue': 'han!'}, {'line': '24', 'name': 'han', 'dialogue': 'yes, your highnessness?'}, {'line': '25', 'name': 'leia', 'dialogue': 'i thought you decided to stay.'}, {'line': '26', 'name': 'han', 'dialogue': 'well, the bounty hunter we ran into on ord mantell changed my  mind.'}, {'line': '27', 'name': 'leia', 'dialogue': 'han, we need you!'}, {'line': '28', 'name': 'han', 'dialogue': 'we?'}, {'line': '29', 'name': 'leia', 'dialogue': 'yes.'}, {'line': '30', 'name': 'han', 'dialogue': 'oh, what about you need?'}, {'line': '31', 'name': 'leia', 'dialogue': "i need? i don't know what you're talking about."}, {'line': '32', 'name': 'han', 'dialogue': "you probably don't."}, {'line': '33', 'name': 'leia', 'dialogue': 'and what precisely am i supposed to know?'}, {'line': '34', 'name': 'han', 'dialogue': 'come on! you want me to stay because of the way you feel about  me.'}, {'line': '35', 'name': 'leia', 'dialogue': "yes. you're a great help to us. you're a natural leader..."}, {'line': '36', 'name': 'han', 'dialogue': "no! that's not it. come on. aahhh -- uh huh! come on."}, {'line': '37', 'name': 'leia', 'dialogue': "you're imagining things."}, {'line': '38', 'name': 'han', 'dialogue': 'am i? then why are you following me? afraid i was going to leave  without giving you a goodbye kiss?'}, {'line': '39', 'name': 'leia', 'dialogue': "i'd just as soon kiss a wookiee."}, {'line': '40', 'name': 'han', 'dialogue': 'i can arrange that. you could use a good kiss!'}, {'line': '41', 'name': 'threepio', 'dialogue': "don't try to blame me. i didn't ask you to turn on the  thermal heater. i merely commented that it was freezing in the princess's chamber. but it's supposed to be freezing. how are we goin ...

# %%
arr = np.array(sw_dic)
name_column = [row['name'] for row in arr]
#print out all character names
print(name_column)
# Out:
# ['luke', 'han', 'luke', 'han', 'luke', 'luke', 'luke', 'han', 'han', 'rieekan', 'han', 'rieekan', 'han', 'rieekan', 'han', 'rieekan', 'han', 'rieekan', 'han', 'han', 'leia', 'han', 'leia', 'han', 'leia', 'han', 'leia', 'han', 'leia', 'han', 'leia', 'han', 'leia', 'han', 'leia', 'han', 'leia', 'han', 'leia', 'han', 'threepio', 'threepio', 'han', 'threepio', 'han', 'threepio', 'han', 'threepio', 'han', 'threepio', 'han', 'threepio', 'han', 'threepio', 'han', 'threepio', 'deck officer', 'han', 'deck officer', 'han', 'deck officer', 'threepio', 'han', 'threepio', 'deck officer', 'han', 'deck officer', 'han', 'deck officer', 'han', 'assistant officer', 'deck officer', 'han', 'threepio', 'threepio', 'lieutenant', 'threepio', 'derlin', 'derlin', 'lieutenant', 'threepio', 'threepio', 'ben', 'luke', 'ben', 'luke', 'ben', 'luke', 'han', 'han', 'luke', 'han', 'luke', 'han', 'luke', 'han', 'luke', 'han', 'zev', 'zev', 'han', 'zev', 'threepio', 'threepio', 'han', 'luke', 'han', 'han', 'leia', 'han', 'leia', 'han', 'han', 'leia', 'han', 'leia', 'announcer', 'han', 'threepio', 'rieekan', 'rieekan', 'senior controller', 'leia', 'han', 'senior controller', 'threepio', 'han', 'rieekan', 'han', 'leia', 'han', 'leia', 'han', 'rieekan
 'han', 'leia', 'han', 'leia', 'han', 'leia', 'han', 'leia', 'han', 'leia', 'han', 'leia', 'han', 'leia', 'han', 'leia', 'han', 'leia', 'threepio', 'han', 'threepio', 'needa', 'vader', 'piett', 'vader', 'piett', 'vader', 'piett', 'vader', 'emperor', 'vader', 'emperor', 'vader', 'emperor', 'vader', 'emperor', 'vader', 'emperor', 'vader', 'luke', 'creature', 'luke', 'creature', 'luke', 'creature', 'luke', 'creature', ...

# %%
#print out how many times each character speaks
c = dict(Counter(name_column))
print(c)
# Out:
# {'luke': 128, 'han': 182, 'rieekan': 13, 'leia': 114, 'threepio': 92, 'deck officer': 7, 'assistant officer': 1, 'lieutenant': 2, 'derlin': 3, 'ben': 15, 'zev': 6, 'announcer': 3, 'senior controller': 2, 'piett': 23, 'ozzel': 5, 'vader': 56, 'rebel captain': 1, 'rebel fighter': 1, 'medical droid': 2, 'controller': 3, 'veers': 7, 'hobbie': 1, 'pilots': 1, 'captain': 1, 'woman controller': 1, 'dack': 4, 'trench officer': 3, 'wedge': 8, 'janson': 4, 'head controller': 1, 'officer': 1, 'second officer': 1, 'pilot': 1, 'imperial officer': 2, 'strange voice': 1, 'creature': 21, 'needa': 5, 'emperor': 5, 'yoda': 36, 'first controller': 1, 'second controller': 1, 'boba fett': 4, 'tracking officer': 2, 'communications officer': 2, 'intercom voice': 2, 'lando': 61, 'second threepio': 1, 'man': 1, 'imperial soldier': 1}

# %%
def most_frequent(name_column):
    counter = 0
    num = name_column[0]
    for i in name_column:
        freq = name_column.count(i)
        if(freq>counter):
            counter = freq
            num = i
    return num
c = dict(Counter(name_column))

# #print the most frequent character
print("The character with the most lines in this episode is:",most_frequent(name_column))
# Out:
# The character with the most lines in this episode is: han

# %%
#print only the character names
d = c.keys()
print(d)
# Out:
# dict_keys(['luke', 'han', 'rieekan', 'leia', 'threepio', 'deck officer', 'assistant officer', 'lieutenant', 'derlin', 'ben', 'zev', 'announcer', 'senior controller', 'piett', 'ozzel', 'vader', 'rebel captain', 'rebel fighter', 'medical droid', 'controller', 'veers', 'hobbie', 'pilots', 'captain', 'woman controller', 'dack', 'trench officer', 'wedge', 'janson', 'head controller', 'officer', 'second officer', 'pilot', 'imperial officer', 'strange voice', 'creature', 'needa', 'emperor', 'yoda', 'first controller', 'second controller', 'boba fett', 'tracking officer', 'communications officer', 'intercom voice', 'lando', 'second threepio', 'man', 'imperial soldier'])

# %%
# #print only the values of how many times each character speaks
e = c.values()
print(e)
# Out:
# dict_values([128, 182, 13, 114, 92, 7, 1, 2, 3, 15, 6, 3, 2, 23, 5, 56, 1, 1, 2, 3, 7, 1, 1, 1, 1, 4, 3, 8, 4, 1, 1, 1, 1, 2, 1, 21, 5, 5, 36, 1, 1, 4, 2, 2, 2, 61, 1, 1, 1])

# %%
#create a bar chart
Character = d
Frequency = e

plt.bar(Character, Frequency)
plt.title('Frequency of Character Lines in SW Episode V')
plt.xlabel('Character')
plt.xticks(rotation = 90)
plt.xticks(fontsize= 7.5)
plt.ylabel('Frequency')
plt.show()
